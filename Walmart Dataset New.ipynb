# %%
import pandas as pd
import numpy as np
df = pd.read_csv('uncleanWalmartData.csv')

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)

# %% [markdown]
# SCROLL ALL THE WAY TO BOTTOM FOR FULL DATABASE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6449 entries, 0 to 6448
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6449 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6442 non-null   float64
#  3   Holiday_Flag  6443 non-null   float64
#  4   Temperature   6432 non-null   float64
#  5   Fuel_Price    6432 non-null   float64
#  6   CPI           6148 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 403.2+ KB

# %%
# Summary of null values
df.isnull().sum()
# Out:
# Store             0
# Date             14
# Weekly_Sales      7
# Holiday_Flag      6
# Temperature      17
# Fuel_Price       17
# CPI             301
# Unemployment     14
# dtype: int64

# %%
# Summary of duplicates
df.duplicated().sum()
# Out:
# 14

# %%
# Find duplicate rows
df[df.duplicated()]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6435      1         NaN    1611968.17           0.0         40.0        2.51
# 6436      1  03-09-2010    1540163.53           0.0         81.0        2.58
# 6437      1  08-10-2010    1508239.93           0.0         64.0        2.63
# 6438      1  12-11-2010    1494479.49           0.0         60.0        2.73
# 6439      4         NaN    2141210.62           0.0         84.0        3.62
# 6440      1  16-07-2010    1448938.92           0.0          NaN        2.62
# 6441      1  23-07-2010    1385065.20           0.0          NaN        2.61
# 6442      4  26-03-2010    1762539.30           0.0         40.0         NaN
# 6443      2  18-11-2011           NaN           0.0         62.0        3.31
# 6444      5  20-07-2012     321205.12           0.0         81.0        3.31
# 6445      6  08-07-2011    1709373.62           0.0         88.0         NaN
# ...

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)
#Replaces orginal DF

# %%
# Summary of null values
df.isnull().sum()
#DATES had null values just removed them below
# Out:
# Store             0
# Date             10
# Weekly_Sales      6
# Holiday_Flag      6
# Temperature      14
# Fuel_Price       14
# CPI             301
# Unemployment     12
# dtype: int64

# %%
#Counting the total number of rows
total_rows = len(df)

# Counting the number of rows with null values
null_rows = df.isnull().any(axis=1).sum()

#Calculating the percentage  of rows with null values
percentage_lost = (null_rows / total_rows) * 100

#Calculating the percentage of retained data
percentage_kept = 100 - percentage_lost

print("Percentage of data kept after removing null values: {:.2f}%".format(percentage_kept))
# Out:
# Percentage of data kept after removing null values: 94.62%

# %%
result = 100 - 94.62
rounded_result = round(result, 2)
print(rounded_result)

#5.38% of data will be taken out if nulls are removed, however will input a few nulls inside the 'df' from doing research online. 
# Then will calculate the new percentage reamaning.
# Out:
# 5.38

# %%
df[df['Date'].isnull()]
#Showing all the null values for the Date coloumn, Will input a date on row index 2 as an estimate
# Out:
#       Store Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 2         1  NaN    1611968.17           0.0         40.0        2.51
# 500       4  NaN    2141210.62           0.0         84.0        3.62
# 536       4  NaN    2226662.17           0.0         41.0        3.54
# 3272     23  NaN    1545370.16           0.0         71.0        3.54
# 3273     23  NaN    1384921.63           0.0         69.0        3.56
# 3274     23  NaN    1381339.23           0.0         71.0        3.61
# 3275     23  NaN    1322932.36           0.0         69.0        3.70
# 3276     23  NaN    1416926.31           0.0         72.0        3.70
# 3277     23  NaN    1436311.76           0.0         71.0        3.77
# 3278     23  NaN    1510131.45           0.0         70.0        3.84
#
#           CPI  Unemployment
# 2     211.289         8.106
# 500   129.043         5.946
# 536   130.550         4.607
# 3272  138.230           NaN
# 3273  138.263           NaN
# ...

# %%
df.loc[2,'Date']= '19-02-2010'
df.loc[500,'Date'] = '17-06-2011'
#Replaced the row index 2, 500 only as a middle number through the dates

# %%
df[df['Date'].isnull()]
# Out:
#       Store Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 536       4  NaN    2226662.17           0.0         41.0        3.54
# 3272     23  NaN    1545370.16           0.0         71.0        3.54
# 3273     23  NaN    1384921.63           0.0         69.0        3.56
# 3274     23  NaN    1381339.23           0.0         71.0        3.61
# 3275     23  NaN    1322932.36           0.0         69.0        3.70
# 3276     23  NaN    1416926.31           0.0         72.0        3.70
# 3277     23  NaN    1436311.76           0.0         71.0        3.77
# 3278     23  NaN    1510131.45           0.0         70.0        3.84
#
#           CPI  Unemployment
# 536   130.550         4.607
# 3272  138.230           NaN
# 3273  138.263           NaN
# 3274  138.233           NaN
# 3275  138.203           NaN
# 3276  138.174           NaN
# 3277  138.144           NaN
# 3278  138.186           NaN

# %%
df.loc[535:537]
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 535      4  17-02-2012    2427640.17           0.0         34.0        3.49
# 536      4         NaN    2226662.17           0.0         41.0        3.54
# 537      4  02-03-2012    2206319.90           0.0         50.0        3.62
#
#          CPI  Unemployment
# 535  130.455         4.607
# 536  130.550         4.607
# 537  130.646         4.607

# %%
df.loc[536,'Date']='24-02-2012'

# %%
df.loc[536:537]
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 536      4  24-02-2012    2226662.17           0.0         41.0        3.54
# 537      4  02-03-2012    2206319.90           0.0         50.0        3.62
#
#          CPI  Unemployment
# 536  130.550         4.607
# 537  130.646         4.607

# %%
df[df['Date'].isnull()]
# Out:
#       Store Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 3272     23  NaN    1545370.16           0.0         71.0        3.54
# 3273     23  NaN    1384921.63           0.0         69.0        3.56
# 3274     23  NaN    1381339.23           0.0         71.0        3.61
# 3275     23  NaN    1322932.36           0.0         69.0        3.70
# 3276     23  NaN    1416926.31           0.0         72.0        3.70
# 3277     23  NaN    1436311.76           0.0         71.0        3.77
# 3278     23  NaN    1510131.45           0.0         70.0        3.84
#
#           CPI  Unemployment
# 3272  138.230           NaN
# 3273  138.263           NaN
# 3274  138.233           NaN
# 3275  138.203           NaN
# 3276  138.174           NaN
# 3277  138.144           NaN
# 3278  138.186           NaN

# %%
# Droping rows with null values as it is diffiuclt to find possible values for these dates 
# Also has null values on Unemployment 
#inplace makes sure it is stcuk within the original data
df.drop(index=range(3272, 3279), inplace=True)

# %%
df[df['Date'].isnull()]
#No more null values on the Date column
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
df.isnull().sum()
# Out:
# Store             0
# Date              0
# Weekly_Sales      6
# Holiday_Flag      6
# Temperature      14
# Fuel_Price       14
# CPI             301
# Unemployment      5
# dtype: int64

# %%
df[df['Weekly_Sales'].isnull()]
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 214      2  17-06-2011           NaN           0.0         87.0        3.64
# 215      2  24-06-2011           NaN           0.0         85.0        3.59
# 216      2  01-07-2011           NaN           0.0         86.0        3.52
# 217      2  08-07-2011           NaN           0.0         88.0        3.48
# 218      2  15-07-2011           NaN           0.0         90.0        3.58
# 236      2  18-11-2011           NaN           0.0         62.0        3.31
#
#          CPI  Unemployment
# 214  214.651         7.931
# 215  214.744         7.931
# 216  214.837         7.852
# 217  214.930         7.852
# 218  215.013         7.852
# 236  217.867         7.441

# %%
df.loc[212:220] 
# looking for any sort of patterns within the weekly sales, however there is none from loooking 
#so will drop these rows
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 212      2  03-06-2011    1933756.21           0.0         83.0        3.70
# 213      2  10-06-2011    1929153.16           0.0         83.0        3.65
# 214      2  17-06-2011           NaN           0.0         87.0        3.64
# 215      2  24-06-2011           NaN           0.0         85.0        3.59
# 216      2  01-07-2011           NaN           0.0         86.0        3.52
# 217      2  08-07-2011           NaN           0.0         88.0        3.48
# 218      2  15-07-2011           NaN           0.0         90.0        3.58
# 219      2  22-07-2011    1743816.41           0.0         89.0        3.65
# 220      2  29-07-2011    1680693.06           0.0         90.0        3.68
#
#          CPI  Unemployment
# 212  214.925         7.931
# 213  214.696         7.931
# 214  214.651         7.931
# 215  214.744         7.931
# 216  214.837         7.852
# 217  214.930         7.852
# ...

# %%
df.drop(index=range(213, 218), inplace=True)

# %%
df.loc[233:241]
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 233      2  28-10-2011    1769296.25           0.0         66.0        3.37
# 234      2  04-11-2011    1959707.90           0.0         56.0        3.33
# 235      2  11-11-2011    1920725.15           0.0         59.0        3.30
# 236      2  18-11-2011           NaN           0.0         62.0        3.31
# 237      2  25-11-2011    2614202.30           1.0         56.0        3.24
# 238      2  02-12-2011    1954952.00           0.0         49.0        3.17
# 239      2  09-12-2011    2290549.32           0.0         42.0        3.16
# 240      2  16-12-2011    2432736.52           0.0         50.0        3.16
# 241      2  23-12-2011    3224369.80           0.0         47.0        3.11
#
#          CPI  Unemployment
# 233  217.325         7.441
# 234  217.485         7.441
# 235  217.646         7.441
# 236  217.867         7.441
# 237  218.113         7.441
# 238  218.359         7.441
# ...

# %%
df.drop(236, inplace = True)

# %%
df[df['Weekly_Sales'].isnull()]
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 218      2  15-07-2011           NaN           0.0         90.0        3.58
#
#          CPI  Unemployment
# 218  215.013         7.852

# %%
df.drop(218, inplace = True)

# %%
df[df['Weekly_Sales'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
df.isnull().sum()
# Out:
# Store             0
# Date              0
# Weekly_Sales      0
# Holiday_Flag      6
# Temperature      14
# Fuel_Price       14
# CPI             301
# Unemployment      5
# dtype: int64

# %%
df[df['Holiday_Flag'].isnull()]
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 360      3  08-07-2011     395146.24           NaN         85.0        3.48
# 361      3  15-07-2011     373454.33           NaN         87.0        3.58
# 362      3  22-07-2011     360617.37           NaN         86.0        3.65
# 363      3  29-07-2011     345381.29           NaN         88.0        3.68
# 364      3  05-08-2011     409981.25           NaN         88.0        3.68
# 365      3  12-08-2011     380376.85           NaN         89.0        3.64
#
#          CPI  Unemployment
# 360  218.642         7.567
# 361  218.728         7.567
# 362  218.786         7.567
# 363  218.844         7.567
# 364  218.902         7.567
# 365  218.961         7.567

# %%
df.loc[355:370] #Checking to see if there is any patterns in Holiday_flag
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 355      3  03-06-2011     394507.84           0.0         84.0        3.70
# 356      3  10-06-2011     391638.75           0.0         85.0        3.65
# 357      3  17-06-2011     403423.34           0.0         87.0        3.64
# 358      3  24-06-2011     385520.71           0.0         85.0        3.59
# 359      3  01-07-2011     368962.72           0.0         85.0        3.52
# 360      3  08-07-2011     395146.24           NaN         85.0        3.48
# 361      3  15-07-2011     373454.33           NaN         87.0        3.58
# 362      3  22-07-2011     360617.37           NaN         86.0        3.65
# 363      3  29-07-2011     345381.29           NaN         88.0        3.68
# 364      3  05-08-2011     409981.25           NaN         88.0        3.68
# 365      3  12-08-2011     380376.85           NaN         89.0        3.64
# ...

# %%
df.drop(index=range(360, 365), inplace=True)

# %%
df.drop(365, inplace=True)

# %%
df[df['Holiday_Flag'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
df.isnull().sum()
# Out:
# Store             0
# Date              0
# Weekly_Sales      0
# Holiday_Flag      0
# Temperature      14
# Fuel_Price       14
# CPI             301
# Unemployment      5
# dtype: int64

# %%
df.loc[20:30] # Checking temperature to see if i can input aproximate temperatures considering month and date(summer)
# Out:
#     Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 20      1  25-06-2010    1422711.60           0.0         84.0        2.65
# 21      1  02-07-2010    1492418.14           0.0         81.0        2.67
# 22      1  09-07-2010    1546074.18           0.0         80.0        2.64
# 23      1  16-07-2010    1448938.92           0.0          NaN        2.62
# 24      1  23-07-2010    1385065.20           0.0          NaN        2.61
# 25      1  30-07-2010    1371986.60           0.0          NaN        2.64
# 26      1  06-08-2010    1605491.78           0.0          NaN        2.63
# 27      1  13-08-2010    1508237.76           0.0         87.0        2.69
# 28      1  20-08-2010    1513080.49           0.0         87.0        2.66
# 29      1  27-08-2010    1449142.92           0.0         85.0        2.62
# 30      1  03-09-2010    1540163.53           0.0         81.0        2.58
#
#         CPI  Unemployment
# 20  211.339         7.808
# ...

# %%
df.loc[23,'Temperature']= '82.0'
df.loc[24,'Temperature'] = '83.0'
df.loc[25,'Temperature']= '85.0'
df.loc[26,'Temperature'] = '86.0'
#Replacing null values with estimated tempertures
# Out:
# C:\Users\omars\AppData\Local\Temp\ipykernel_13504\4103433558.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '82.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[23,'Temperature']= '82.0'

# %%
df[df['Temperature'].isnull()]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag Temperature  Fuel_Price  \
# 3845     27  13-07-2012    1755889.53           0.0         NaN         NaN
# 3846     27  20-07-2012    1730913.66           0.0         NaN         NaN
# 3847     27  27-07-2012    1625883.71           0.0         NaN         NaN
# 3848     27  03-08-2012    1705810.84           0.0         NaN         NaN
# 3849     27  10-08-2012    1720537.26           0.0         NaN         NaN
# 3850     27  17-08-2012    1735339.59           0.0         NaN         NaN
# 3851     27  24-08-2012    1780443.36           0.0         NaN         NaN
# 3852     27  31-08-2012    1731935.43           0.0         NaN         NaN
# 3853     27  07-09-2012    1840955.23           1.0         NaN         NaN
# 3854     27  14-09-2012    1519604.50           0.0         NaN         NaN
#
#           CPI  Unemployment
# 3845  142.255         8.239
# 3846  142.234         8.239
# 3847  142.213         8.239
# ...

# %%
df.loc[3840:3858]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag Temperature  Fuel_Price  \
# 3840     27  08-06-2012    1764756.31           0.0        64.0        3.87
# 3841     27  15-06-2012    1773500.56           0.0        70.0        3.79
# 3842     27  22-06-2012    1837884.79           0.0        73.0        3.72
# 3843     27  29-06-2012    1842555.32           0.0        74.0        3.67
# 3844     27  06-07-2012    2062224.92           0.0        82.0        3.65
# 3845     27  13-07-2012    1755889.53           0.0         NaN         NaN
# 3846     27  20-07-2012    1730913.66           0.0         NaN         NaN
# 3847     27  27-07-2012    1625883.71           0.0         NaN         NaN
# 3848     27  03-08-2012    1705810.84           0.0         NaN         NaN
# 3849     27  10-08-2012    1720537.26           0.0         NaN         NaN
# 3850     27  17-08-2012    1735339.59           0.0         NaN         NaN
# ...

# %%
df.loc[3845,'Temperature']= '82.0'
df.loc[3846,'Temperature'] = '84.0'
df.loc[3847,'Temperature']= '85.0'
df.loc[3848,'Temperature'] = '84.0'
df.loc[3849,'Temperature']= '82.0'
df.loc[3850,'Temperature'] = '80.0'
df.loc[3851,'Temperature']= '75.0'
df.loc[3852,'Temperature'] = '73.0'
df.loc[3853,'Temperature']= '70.0'
df.loc[3854,'Temperature'] = '68.0'


#Instead of dropping all the data will be replacing with analytical thinking

# %%
df[df['Temperature'].isnull()]   #No more null values on temperature and saving data loss
                                # will likley do the same for fuel prices
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
df.isnull().sum()
# Out:
# Store             0
# Date              0
# Weekly_Sales      0
# Holiday_Flag      0
# Temperature       0
# Fuel_Price       14
# CPI             301
# Unemployment      5
# dtype: int64

# %%
df[df['Fuel_Price'].isnull()]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag Temperature  Fuel_Price  \
# 436       4  26-03-2010    1762539.30           0.0        40.0         NaN
# 437       4  02-04-2010    1979247.12           0.0        49.0         NaN
# 438       4  09-04-2010    1818452.72           0.0        54.0         NaN
# 789       6  08-07-2011    1709373.62           0.0        88.0         NaN
# 3845     27  13-07-2012    1755889.53           0.0        82.0         NaN
# 3846     27  20-07-2012    1730913.66           0.0        84.0         NaN
# 3847     27  27-07-2012    1625883.71           0.0        85.0         NaN
# 3848     27  03-08-2012    1705810.84           0.0        84.0         NaN
# 3849     27  10-08-2012    1720537.26           0.0        82.0         NaN
# 3850     27  17-08-2012    1735339.59           0.0        80.0         NaN
# 3851     27  24-08-2012    1780443.36           0.0        75.0         NaN
# ...

# %%
df.loc[430:445]
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag Temperature  Fuel_Price  \
# 430      4  12-02-2010    2188307.39           1.0        29.0        2.57
# 431      4  19-02-2010    2049860.26           0.0        36.0        2.54
# 432      4  26-02-2010    1925728.84           0.0        41.0        2.59
# 433      4  05-03-2010    1971057.44           0.0        43.0        2.65
# 434      4  12-03-2010    1894324.09           0.0        50.0        2.70
# 435      4  19-03-2010    1897429.36           0.0        55.0        2.74
# 436      4  26-03-2010    1762539.30           0.0        40.0         NaN
# 437      4  02-04-2010    1979247.12           0.0        49.0         NaN
# 438      4  09-04-2010    1818452.72           0.0        54.0         NaN
# 439      4  16-04-2010    1851519.69           0.0        56.0        2.81
# 440      4  23-04-2010    1802677.90           0.0        57.0        2.80
# ...

# %%
df.loc[436,'Fuel_Price']= '2.75'
df.loc[337,'Fuel_Price']= '2.77'
df.loc[438,'Fuel_Price']= '2.80'
# Out:
# C:\Users\omars\AppData\Local\Temp\ipykernel_13504\566950192.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.75' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[436,'Fuel_Price']= '2.75'

# %%
df.loc[780:795]
# Out:
#      Store        Date  Weekly_Sales  Holiday_Flag Temperature Fuel_Price  \
# 780      6  06-05-2011    1504651.57           0.0        65.0       3.91
# 781      6  13-05-2011    1453185.65           0.0        77.0        3.9
# 782      6  20-05-2011    1382783.83           0.0        72.0       3.91
# 783      6  27-05-2011    1523979.11           0.0        81.0       3.79
# 784      6  03-06-2011    1705506.29           0.0        84.0        3.7
# 785      6  10-06-2011    1598643.65           0.0        84.0       3.65
# 786      6  17-06-2011    1622150.33           0.0        87.0       3.64
# 787      6  24-06-2011    1543365.90           0.0        86.0       3.59
# 788      6  01-07-2011    1694551.15           0.0        87.0       3.52
# 789      6  08-07-2011    1709373.62           0.0        88.0        NaN
# 790      6  15-07-2011    1526801.24           0.0        89.0       3.58
# 791      6  22-07-2011    1526506.08           0.0        88.0       3.65
# ...

# %%
df.loc[438,'Fuel_Price']= '3.55'

# %%
df.loc[3840:3860]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag Temperature Fuel_Price  \
# 3840     27  08-06-2012    1764756.31           0.0        64.0       3.87
# 3841     27  15-06-2012    1773500.56           0.0        70.0       3.79
# 3842     27  22-06-2012    1837884.79           0.0        73.0       3.72
# 3843     27  29-06-2012    1842555.32           0.0        74.0       3.67
# 3844     27  06-07-2012    2062224.92           0.0        82.0       3.65
# 3845     27  13-07-2012    1755889.53           0.0        82.0        NaN
# 3846     27  20-07-2012    1730913.66           0.0        84.0        NaN
# 3847     27  27-07-2012    1625883.71           0.0        85.0        NaN
# 3848     27  03-08-2012    1705810.84           0.0        84.0        NaN
# 3849     27  10-08-2012    1720537.26           0.0        82.0        NaN
# 3850     27  17-08-2012    1735339.59           0.0        80.0        NaN
# ...

# %%
df.loc[3845,'Fuel_Price']= '3.64'
df.loc[3846,'Fuel_Price']= '3.65'
df.loc[3847,'Fuel_Price']= '3.66'
df.loc[3848,'Fuel_Price']= '3.70'
df.loc[3849,'Fuel_Price']= '3.75'
df.loc[3850,'Fuel_Price']= '3.78'
df.loc[3851,'Fuel_Price']= '3.80'
df.loc[3852,'Fuel_Price']= '3.85'
df.loc[3853,'Fuel_Price']= '3.90'
df.loc[3854,'Fuel_Price']= '4.10'
df.loc[3855,'Fuel_Price']= '4.20'

# %%
df.loc[437,'Fuel_Price']= '2.77'
df.loc[789,'Fuel_Price']= '3.55'

# %%
df[df['Fuel_Price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
df.isnull().sum()
# Out:
# Store             0
# Date              0
# Weekly_Sales      0
# Holiday_Flag      0
# Temperature       0
# Fuel_Price        0
# CPI             301
# Unemployment      5
# dtype: int64

# %%
df[df['Unemployment'].isnull()]
# Out:
#     Store        Date  Weekly_Sales  Holiday_Flag Temperature Fuel_Price  \
# 3       1  26-02-2010    1409727.59           0.0        47.0       2.56
# 4       1  05-03-2010    1554806.68           0.0        46.0       2.62
# 5       1  12-03-2010    1439541.59           0.0        58.0       2.67
# 6       1  19-03-2010    1472515.79           0.0        55.0       2.72
# 60      1  01-04-2011    1495064.75           0.0        59.0       3.52
#
#         CPI  Unemployment
# 3   211.320           NaN
# 4   211.350           NaN
# 5   211.381           NaN
# 6   211.216           NaN
# 60  214.837           NaN

# %%
df.loc[1:10]
# Out:
#     Store        Date  Weekly_Sales  Holiday_Flag Temperature Fuel_Price  \
# 1       1  12-02-2010    1641957.44           1.0        39.0       2.55
# 2       1  19-02-2010    1611968.17           0.0        40.0       2.51
# 3       1  26-02-2010    1409727.59           0.0        47.0       2.56
# 4       1  05-03-2010    1554806.68           0.0        46.0       2.62
# 5       1  12-03-2010    1439541.59           0.0        58.0       2.67
# 6       1  19-03-2010    1472515.79           0.0        55.0       2.72
# 7       1  26-03-2010    1404429.92           0.0        51.0       2.73
# 8       1  02-04-2010    1594968.28           0.0        62.0       2.72
# 9       1  09-04-2010    1545418.53           0.0        66.0       2.77
# 10      1  16-04-2010    1466058.28           0.0        66.0       2.81
#
#         CPI  Unemployment
# 1   211.242         8.106
# 2   211.289         8.106
# 3   211.320           NaN
# 4   211.350           NaN
# 5   211.381           NaN
# ...

# %%
df.loc[3,'Unemployment']= '8.106'
df.loc[4,'Unemployment']= '8.106'
df.loc[5,'Unemployment']= '8.106'
df.loc[6,'Unemployment']= '8.106'
# Out:
# C:\Users\omars\AppData\Local\Temp\ipykernel_13504\3159110997.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.106' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[3,'Unemployment']= '8.106'

# %%
df.loc[55:65]
# Out:
#     Store        Date  Weekly_Sales  Holiday_Flag Temperature Fuel_Price  \
# 55      1  25-02-2011    1456800.28           0.0        63.0       3.06
# 56      1  04-03-2011    1636263.41           0.0        60.0       3.29
# 57      1  11-03-2011    1553191.63           0.0        54.0       3.46
# 58      1  18-03-2011    1576818.06           0.0        63.0       3.49
# 59      1  25-03-2011    1541102.38           0.0        70.0       3.47
# 60      1  01-04-2011    1495064.75           0.0        59.0       3.52
# 61      1  08-04-2011    1614259.35           0.0        68.0       3.62
# 62      1  15-04-2011    1559889.00           0.0        71.0       3.74
# 63      1  22-04-2011    1564819.81           0.0        73.0       3.81
# 64      1  29-04-2011    1455090.69           0.0        72.0       3.81
# 65      1  06-05-2011    1629391.28           0.0        65.0       3.91
#
#         CPI Unemployment
# 55  213.536        7.742
# 56  213.823        7.742
# ...

# %%
df.loc[60,'Unemployment']= '7.742'   #Replaced with analytcila thinking by checking trends in the unemplyment coloumn

# %%
df.isnull().sum()
# Out:
# Store             0
# Date              0
# Weekly_Sales      0
# Holiday_Flag      0
# Temperature       0
# Fuel_Price        0
# CPI             301
# Unemployment      0
# dtype: int64

# %%
#Large amount of CPI data missing will first look at 
df[df['CPI'].isnull()]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag Temperature Fuel_Price  \
# 6000     42  21-09-2012     527165.70           0.0        82.0       4.12
# 6001     42  28-09-2012     505978.46           0.0        83.0       3.97
# 6002     42  05-10-2012     593162.53           0.0        81.0       4.13
# 6003     42  12-10-2012     612379.90           0.0        76.0       4.47
# 6004     42  19-10-2012     541406.98           0.0        73.0       4.45
# 6005     42  26-10-2012     514756.08           0.0        70.0        4.3
# 6006     43  05-02-2010     647029.28           0.0        47.0       2.57
# 6007     43  12-02-2010     682918.99           1.0        48.0       2.55
# 6008     43  19-02-2010     658997.55           0.0        49.0       2.51
# 6009     43  26-02-2010     618702.79           0.0        49.0       2.56
# 6010     43  05-03-2010     658600.05           0.0        53.0       2.62
# ...

# %%
#Difficult to find any good patterns or trends to be able to input values in the CPI,
#so will then look at how much data will be lost if i remove 301 rows 


#Counting the total number of rows
total_rows = len(df)

# Counting the number of rows with null values
null_rows = df.isnull().any(axis=1).sum()

#Calculating the percentage  of rows with null values
percentage_lost = (null_rows / total_rows) * 100

#Calculating the percentage of retained data
percentage_kept = 100 - percentage_lost

print("Percentage of data kept after removing null values: {:.2f}%".format(percentage_kept))
# Out:
# Percentage of data kept after removing null values: 95.31%

# %%
result = 100 - 95.31
rounded_result = round(result, 2)
print(rounded_result)
#4.69& of data will be taken out which is a very small amount in order to to my data visulisation.
# Out:
# 4.69

# %%
df.drop(index=range(6000, 6300), inplace=True)

# %%
df.drop(6300, inplace=True)

# %%
df.isnull().sum() #NO LONGER ANY NULLS OR DUPLICATES WHICH MEANS DATA IS NOW CLEANED in nulls and duplicates
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
# Rounding the values 2 decimal places
df['CPI'] = df['CPI'].round(2)
df['Unemployment'] = df['Unemployment'].round(2)

# %%
# Rounding the values in the 'Temperature' column to 0 decimal places 
df['Temperature'] = df['Temperature'].round(0)

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag Temperature Fuel_Price  \
# 0         1  05-02-2010    1643690.90           0.0        42.0       2.57
# 1         1  12-02-2010    1641957.44           1.0        39.0       2.55
# 2         1  19-02-2010    1611968.17           0.0        40.0       2.51
# 3         1  26-02-2010    1409727.59           0.0        47.0       2.56
# 4         1  05-03-2010    1554806.68           0.0        46.0       2.62
# 5         1  12-03-2010    1439541.59           0.0        58.0       2.67
# 6         1  19-03-2010    1472515.79           0.0        55.0       2.72
# 7         1  26-03-2010    1404429.92           0.0        51.0       2.73
# 8         1  02-04-2010    1594968.28           0.0        62.0       2.72
# 9         1  09-04-2010    1545418.53           0.0        66.0       2.77
# 10        1  16-04-2010    1466058.28           0.0        66.0       2.81
# ...

# %%
df.to_csv('CLEANED_DATASET_PYTHON.csv', index=False)
